# %% [markdown]
# <a href="https://colab.research.google.com/github/bandreddysukanya/Book-Store/blob/main/Unemployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-31495669-53aa-45ca-87dd-71c8a81115fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31495669-53aa-45ca-87dd-71c8a81115fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e74d3929-ce7f-4b88-81e2-50ddb3e1e88c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e74d3929-ce7f-4b88-81e2-50ddb3e1e88c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
ps=pd.read_csv("Unemployment_Rate_upto_11_2020.csv")

# %%
st=pd.read_csv("Unemployment in India.csv")

# %%
ps
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
st
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
st.sample(10)
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 568  Madhya Pradesh   31-12-2019    Monthly                              6.20
# 350     West Bengal   31-10-2019    Monthly                              6.78
# 55            Delhi   30-06-2019    Monthly                              9.33
# 78              Goa   30-04-2020    Monthly                             15.91
# 262       Rajasthan   31-10-2019    Monthly                             14.66
# 693       Telangana   29-02-2020    Monthly                              6.74
# 402           Bihar   30-06-2019    Monthly                             13.29
# 521       Jharkhand   31-07-2019    Monthly                             15.67
# 348     West Bengal   31-08-2019    Monthly                              5.58
# 287      Tamil Nadu   30-04-2020    Monthly                             53.19
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# ...

# %%
ps.sample(8)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 249   Uttarakhand   31-03-2020          M                             19.85
# 144   Maharashtra   30-06-2020          M                              9.23
# 230       Tripura   30-04-2020          M                             41.23
# 211    Tamil Nadu   31-05-2020          M                             33.16
# 32   Chhattisgarh   31-03-2020          M                              7.54
# 183        Punjab   31-05-2020          M                             28.33
# 99      Jharkhand   31-01-2020          M                             10.61
# 74        Haryana   31-05-2020          M                             29.02
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Region.1  \
# 249              2539302                                     36.27      North
# 144             39708538                                     42.71       West
# ...

# %%
ps.shape
# Out:
# (267, 9)

# %%
st.shape
# Out:
# (754, 7)

# %%
print("Rows--->",st.shape[0])
# Out:
# Rows---> 754

# %%
print("Rows--->",ps.shape[0])
# Out:
# Rows---> 267

# %%
print("Columns--->",ps.shape[0])
# Out:
# Columns---> 267

# %%
print("Columns--->",st.shape[0])
# Out:
# Columns---> 754

# %%
ps.isnull()
# Out:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 262   False  False       False                             False
# 263   False  False       False                             False
# 264   False  False       False                             False
# 265   False  False       False                             False
# 266   False  False       False                             False
#
#       Estimated Employed   Estimated Labour Participation Rate (%)  Region.1  \
# 0                  False                                     False     False
# ...

# %%
st.isnull()
# Out:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 749   False  False       False                             False
# 750   False  False       False                             False
# 751   False  False       False                             False
# 752   False  False       False                             False
# 753   False  False       False                             False
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0                  False                                     False  False
# ...

# %%
st.isnull().sum()
# Out:
# Region                                      14
#  Date                                       14
#  Frequency                                  14
#  Estimated Unemployment Rate (%)            14
#  Estimated Employed                         14
#  Estimated Labour Participation Rate (%)    14
# Area                                        14
# dtype: int64

# %%
ps.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
ps.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
st.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.4+ KB

# %%
st.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
ps.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
print(st.describe)
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
print(ps.describe)
# Out:
# <bound method NDFrame.describe of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
st.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 749    False
# 750    False
# 751    False
# 752    False
# 753    False
# Length: 754, dtype: bool

# %%
ps.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 262    False
# 263    False
# 264    False
# 265    False
# 266    False
# Length: 267, dtype: bool

# %%
ps.duplicated().sum()
# Out:
# 0

# %%
st.duplicated().sum()
# Out:
# 13

# %%
st.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object

# %%
ps.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                           int64
#  Estimated Labour Participation Rate (%)    float64
# Region.1                                     object
# longitude                                   float64
# latitude                                    float64
# dtype: object

# %%
ps.columns=['Region','Date','Frequency','Estimated unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','Region.1','longitude','latitude']

# %%
ps
# Out:
#              Region         Date Frequency  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-01-2020         M                         5.48
# 1    Andhra Pradesh   29-02-2020         M                         5.83
# 2    Andhra Pradesh   31-03-2020         M                         5.79
# 3    Andhra Pradesh   30-04-2020         M                        20.51
# 4    Andhra Pradesh   31-05-2020         M                        17.43
# ..              ...          ...       ...                          ...
# 262     West Bengal   30-06-2020         M                         7.29
# 263     West Bengal   31-07-2020         M                         6.83
# 264     West Bengal   31-08-2020         M                        14.87
# 265     West Bengal   30-09-2020         M                         9.35
# 266     West Bengal   31-10-2020         M                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region.1  \
# ...

# %%
st.columns=['Region','Date','Frequency','Estimated unemployment Rate','Estimated Employed','Estimated Labour Participation Rate','Area']

# %%
st
# Out:
#              Region         Date Frequency  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                         5.17
# ..              ...          ...       ...                          ...
# 749     West Bengal   29-02-2020   Monthly                         7.55
# 750     West Bengal   31-03-2020   Monthly                         6.67
# 751     West Bengal   30-04-2020   Monthly                        15.63
# 752     West Bengal   31-05-2020   Monthly                        15.22
# 753     West Bengal   30-06-2020   Monthly                         9.86
#
#      Estimated Employed  Estimated Labour Participation Rate   Area
# ...

# %%
st[['Day','Month','Year']]=st['Date'].str.split('-',expand=True)

# %%
st
# Out:
#              Region         Date Frequency  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019   Monthly                         3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                         3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                         3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                         3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                         5.17
# ..              ...          ...       ...                          ...
# 749     West Bengal   29-02-2020   Monthly                         7.55
# 750     West Bengal   31-03-2020   Monthly                         6.67
# 751     West Bengal   30-04-2020   Monthly                        15.63
# 752     West Bengal   31-05-2020   Monthly                        15.22
# 753     West Bengal   30-06-2020   Monthly                         9.86
#
#      Estimated Employed  Estimated Labour Participation Rate   Area  Day  \
# ...

# %%
ps[['Day','Month','Year']]=ps['Date'].str.split('-',expand=True)

# %%
ps
# Out:
#              Region         Date Frequency  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-01-2020         M                         5.48
# 1    Andhra Pradesh   29-02-2020         M                         5.83
# 2    Andhra Pradesh   31-03-2020         M                         5.79
# 3    Andhra Pradesh   30-04-2020         M                        20.51
# 4    Andhra Pradesh   31-05-2020         M                        17.43
# ..              ...          ...       ...                          ...
# 262     West Bengal   30-06-2020         M                         7.29
# 263     West Bengal   31-07-2020         M                         6.83
# 264     West Bengal   31-08-2020         M                        14.87
# 265     West Bengal   30-09-2020         M                         9.35
# 266     West Bengal   31-10-2020         M                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region.1  \
# ...

# %%
ps.drop(columns=['Frequency'],axis=0,inplace=True)

# %%
ps
# Out:
#              Region         Date  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-01-2020                         5.48
# 1    Andhra Pradesh   29-02-2020                         5.83
# 2    Andhra Pradesh   31-03-2020                         5.79
# 3    Andhra Pradesh   30-04-2020                        20.51
# 4    Andhra Pradesh   31-05-2020                        17.43
# ..              ...          ...                          ...
# 262     West Bengal   30-06-2020                         7.29
# 263     West Bengal   31-07-2020                         6.83
# 264     West Bengal   31-08-2020                        14.87
# 265     West Bengal   30-09-2020                         9.35
# 266     West Bengal   31-10-2020                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region.1  \
# 0              16635535                                41.02    South
# 1              16545652                                40.90    South
# ...

# %%
st.drop(columns=['Frequency'],axis=0,inplace=True)

# %%
st
# Out:
#              Region         Date  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019                         3.65
# 1    Andhra Pradesh   30-06-2019                         3.05
# 2    Andhra Pradesh   31-07-2019                         3.75
# 3    Andhra Pradesh   31-08-2019                         3.32
# 4    Andhra Pradesh   30-09-2019                         5.17
# ..              ...          ...                          ...
# 749     West Bengal   29-02-2020                         7.55
# 750     West Bengal   31-03-2020                         6.67
# 751     West Bengal   30-04-2020                        15.63
# 752     West Bengal   31-05-2020                        15.22
# 753     West Bengal   30-06-2020                         9.86
#
#      Estimated Employed  Estimated Labour Participation Rate   Area  Day  \
# 0            11999139.0                                43.24  Rural   31
# ...

# %%
st[:0]
# Out:
# Empty DataFrame
# Columns: [Region, Date, Estimated unemployment Rate, Estimated Employed, Estimated Labour Participation Rate, Area, Day, Month, Year]
# Index: []

# %%
st[:12]
# Out:
#             Region         Date  Estimated unemployment Rate  \
# 0   Andhra Pradesh   31-05-2019                         3.65
# 1   Andhra Pradesh   30-06-2019                         3.05
# 2   Andhra Pradesh   31-07-2019                         3.75
# 3   Andhra Pradesh   31-08-2019                         3.32
# 4   Andhra Pradesh   30-09-2019                         5.17
# 5   Andhra Pradesh   31-10-2019                         3.52
# 6   Andhra Pradesh   30-11-2019                         4.12
# 7   Andhra Pradesh   31-12-2019                         4.38
# 8   Andhra Pradesh   31-01-2020                         4.84
# 9   Andhra Pradesh   29-02-2020                         5.91
# 10  Andhra Pradesh   31-03-2020                         4.06
# 11  Andhra Pradesh   30-04-2020                        16.29
#
#     Estimated Employed  Estimated Labour Participation Rate   Area  Day Month  \
# 0           11999139.0                                43.24  Rural   31    05
# ...

# %%
ps[:0]
# Out:
# Empty DataFrame
# Columns: [Region, Date, Estimated unemployment Rate, Estimated Employed, Estimated Labour Participation Rate, Region.1, longitude, latitude, Day, Month, Year]
# Index: []

# %%
ps[:10]
# Out:
#            Region         Date  Estimated unemployment Rate  \
# 0  Andhra Pradesh   31-01-2020                         5.48
# 1  Andhra Pradesh   29-02-2020                         5.83
# 2  Andhra Pradesh   31-03-2020                         5.79
# 3  Andhra Pradesh   30-04-2020                        20.51
# 4  Andhra Pradesh   31-05-2020                        17.43
# 5  Andhra Pradesh   30-06-2020                         3.31
# 6  Andhra Pradesh   31-07-2020                         8.34
# 7  Andhra Pradesh   31-08-2020                         6.96
# 8  Andhra Pradesh   30-09-2020                         6.40
# 9  Andhra Pradesh   31-10-2020                         6.59
#
#    Estimated Employed  Estimated Labour Participation Rate Region.1  \
# 0            16635535                                41.02    South
# 1            16545652                                40.90    South
# 2            15881197                                39.18    South
# ...

# %%
sns.heatmap(st.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-53-22ccdddce929>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(st.corr(),annot=True)

# %%
sns.heatmap(ps.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-54-ba252a351f0e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ps.corr(),annot=True)

# %%
st.Region.value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
ps.Region.value_counts()
# Out:
# Andhra Pradesh      10
# Assam               10
# Uttarakhand         10
# Uttar Pradesh       10
# Tripura             10
# Telangana           10
# Tamil Nadu          10
# Rajasthan           10
# Punjab              10
# Puducherry          10
# Odisha              10
# Meghalaya           10
# Maharashtra         10
# Madhya Pradesh      10
# Kerala              10
# Karnataka           10
# Jharkhand           10
# Himachal Pradesh    10
# Haryana             10
# Gujarat             10
# Goa                 10
# Delhi               10
# Chhattisgarh        10
# Bihar               10
# West Bengal         10
# Jammu & Kashmir      9
# Sikkim               8
# Name: Region, dtype: int64

# %%
st.columns
plt.title("Indian Unemployment")
sns.histplot(x="Estimated Employed",hue="Region",data=st)
# Out:
# <Axes: title={'center': 'Indian Unemployment'}, xlabel='Estimated Employed', ylabel='Count'>

# %%
ps.columns
plt.title("Indian Unemployment")
sns.histplot(x="Estimated Employed",hue="Region",data=ps)
# Out:
# <Axes: title={'center': 'Indian Unemployment'}, xlabel='Estimated Employed', ylabel='Count'>

# %%
plt.figure(figsize=(5,6))
plt.title('Indian Unemployment')
sns.histplot(x="Estimated unemployment Rate", hue="Region",data=st)
plt.show()

# %%
fg=px.bar(ps,x='Region',y='Estimated unemployment Rate',title='Indian unemployment rate(state-wise)',template='plotly',color='Region')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ps
# Out:
#              Region         Date  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-01-2020                         5.48
# 1    Andhra Pradesh   29-02-2020                         5.83
# 2    Andhra Pradesh   31-03-2020                         5.79
# 3    Andhra Pradesh   30-04-2020                        20.51
# 4    Andhra Pradesh   31-05-2020                        17.43
# ..              ...          ...                          ...
# 262     West Bengal   30-06-2020                         7.29
# 263     West Bengal   31-07-2020                         6.83
# 264     West Bengal   31-08-2020                        14.87
# 265     West Bengal   30-09-2020                         9.35
# 266     West Bengal   31-10-2020                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region.1  \
# 0              16635535                                41.02    South
# 1              16545652                                40.90    South
# ...

# %%
fg=px.bar(st,x='Region',y='Estimated unemployment Rate',title='Indian unemployment rate(state-wise)',template='plotly',color='Region')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ps.Month.unique()
# Out:
# array(['01', '02', '03', '04', '05', '06', '07', '08', '09', '10'],
#       dtype=object)

# %%
st.Month.unique()
# Out:
# array(['05', '06', '07', '08', '09', '10', '11', '12', '01', '02', '03',
#        '04', nan], dtype=object)

# %%
sns.barplot(x="Month",y="Estimated unemployment Rate",hue="Year",data=ps)
# Out:
# <Axes: xlabel='Month', ylabel='Estimated unemployment Rate'>

# %%
sns.barplot(x="Month",y="Estimated unemployment Rate",hue="Year",data=st)
# Out:
# <Axes: xlabel='Month', ylabel='Estimated unemployment Rate'>

# %%
ps.Day.unique()
# Out:
# array([' 31', ' 29', ' 30'], dtype=object)

# %%
st.Day.unique()
# Out:
# array([' 31', ' 30', ' 29', nan], dtype=object)

# %%
sns.barplot(x="Day",y="Estimated unemployment Rate",hue="Year",data=ps)
# Out:
# <Axes: xlabel='Day', ylabel='Estimated unemployment Rate'>

# %%
sns.barplot(x="Day",y="Estimated unemployment Rate",hue="Year",data=st)
# Out:
# <Axes: xlabel='Day', ylabel='Estimated unemployment Rate'>

# %%
sns.set_theme(style="ticks",palette="pastel")
sns.boxplot(x="Month" , y='Estimated Employed', palette=["m", "g"],data=ps)
sns.despine(offset=10,trin=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-3355298476f1> in <cell line: 3>()
#       1 sns.set_theme(style="ticks",palette="pastel")
#       2 sns.boxplot(x="Month" , y='Estimated Employed', palette=["m", "g"],data=ps)
# ----> 3 sns.despine(offset=10,trin=True)
#
# TypeError: despine() got an unexpected keyword argument 'trin'

# %%
st.drop(columns=['Year'],axis=1)
# Out:
#              Region         Date  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-05-2019                         3.65
# 1    Andhra Pradesh   30-06-2019                         3.05
# 2    Andhra Pradesh   31-07-2019                         3.75
# 3    Andhra Pradesh   31-08-2019                         3.32
# 4    Andhra Pradesh   30-09-2019                         5.17
# ..              ...          ...                          ...
# 749     West Bengal   29-02-2020                         7.55
# 750     West Bengal   31-03-2020                         6.67
# 751     West Bengal   30-04-2020                        15.63
# 752     West Bengal   31-05-2020                        15.22
# 753     West Bengal   30-06-2020                         9.86
#
#      Estimated Employed  Estimated Labour Participation Rate   Area  Day Month
# 0            11999139.0                                43.24  Rural   31    05
# ...

# %%
ps.drop(columns=['Year'],axis=1)
# Out:
#              Region         Date  Estimated unemployment Rate  \
# 0    Andhra Pradesh   31-01-2020                         5.48
# 1    Andhra Pradesh   29-02-2020                         5.83
# 2    Andhra Pradesh   31-03-2020                         5.79
# 3    Andhra Pradesh   30-04-2020                        20.51
# 4    Andhra Pradesh   31-05-2020                        17.43
# ..              ...          ...                          ...
# 262     West Bengal   30-06-2020                         7.29
# 263     West Bengal   31-07-2020                         6.83
# 264     West Bengal   31-08-2020                        14.87
# 265     West Bengal   30-09-2020                         9.35
# 266     West Bengal   31-10-2020                         9.98
#
#      Estimated Employed  Estimated Labour Participation Rate Region.1  \
# 0              16635535                                41.02    South
# 1              16545652                                40.90    South
# ...

# %%
plt.figure(figsize=[8,8])
plt.title('Indian unemployement')
sns.boxplot(x="Month",y="Estimated unemployment Rate",hue="Region",data=st)
plt.show()

# %%
plt.figure(figsize=[9,9])
plt.title('Indian unemployement')
sns.boxplot(x="Month",y="Estimated unemployment Rate",hue="Region",data=ps)
plt.show()

# %%
plt.title('Indian unemployment')
sns.boxplot(x="Day",y="Estimated unemployment Rate",hue="Region",data=ps)
plt.show()

# %%
plt.title('Indian unemployment')
sns.boxplot(x="Day",y="Estimated unemployment Rate",hue="Region",data=st)
plt.show()

# %%
fg=px.scatter(st,x='Region',y='Estimated unemployment Rate',title='Indian unemployment rate(state-wise)',template='plotly',color='Region')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fg=px.scatter(ps,x='Region',y='Estimated unemployment Rate',title='Indian unemployment rate(state-wise)',template='plotly',color='Region')
fg.update_layout(xaxis={'categoryorder':'total descending'})
fg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
